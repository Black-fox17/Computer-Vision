# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\owner\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('best.pt')
results = model.predict('129.mp4',save=True)
print(results[0])
print('=====================================')
for box in results[0].boxes:
    print(box)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/6078) c:\Users\owner\Desktop\Projects\Football\129.mp4: 384x640 (no detections), 2034.6ms
# video 1/1 (frame 2/6078) c:\Users\owner\Desktop\Projects\Football\129.mp4: 384x640 (no detections), 2026.4ms
# video 1/1 (frame 3/6078) c:\Users\owner\Desktop\Projects\Football\129.mp4: 384x640 (no detections), 1951.1ms
# ...
