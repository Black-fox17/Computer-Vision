# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 44.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')
results = model.predict('/content/drive/MyDrive/Football/129.mp4',save=True)
print(results[0])
print('=====================================')
for box in results[0].boxes:
    print(box)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 78.7MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/6078) /content/drive/MyDrive/Football/129.mp4: 384x640 (no detections), 383.7ms
# video 1/1 (frame 2/6078) /content/drive/MyDrive/Football/129.mp4: 384x640 (no detections), 171.1ms
# video 1/1 (frame 3/6078) /content/drive/MyDrive/Football/129.mp4: 384x640 (no detections), 166.6ms
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="lZGotTmYyJM0UU2mNjEx")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 1642.70it/s]

# %%
import os
import shutil

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
os.mkdir("/content/football-players-detection-1/football-players-detection-1")

# %%
shutil.move("/content/football-players-detection-1/train","/content/football-players-detection-1/football-players-detection-1/train")
shutil.move("/content/football-players-detection-1/test","/content/football-players-detection-1/football-players-detection-1/test")
shutil.move("/content/football-players-detection-1/valid","/content/football-players-detection-1/football-players-detection-1/valid")
# Out:
# '/content/football-players-detection-1/football-players-detection-1/valid'

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=10 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 186M/186M [00:05<00:00, 33.8MB/s]
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/Football
# !cp /content/runs/detect/train/weights/last.pt /content/drive/MyDrive/Football
